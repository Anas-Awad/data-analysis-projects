# %% [markdown]
# ### Importing libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as pl
import plotly.express as px
# %matplotlib inline
sns.set_theme(context = 'poster' , style = 'ticks' , palette = 'Greys_r' , font_scale = 0.7 , rc = {'figure.figsize':[21 , 9]})

# %% [markdown]
# ### pd.read_csv - To import the CSV file in Jupyter notebook

# %%
df = pd.read_csv('Police Data.csv')
df
# Out:
#        stop_date stop_time  country_name driver_gender  driver_age_raw  \
# 0       1/2/2005      1:55           NaN             M          1985.0
# 1      1/18/2005      8:15           NaN             M          1965.0
# 2      1/23/2005     23:15           NaN             M          1972.0
# 3      2/20/2005     17:15           NaN             M          1986.0
# 4      3/14/2005     10:00           NaN             F          1984.0
# ...          ...       ...           ...           ...             ...
# 65530  12/6/2012     17:54           NaN             F          1987.0
# 65531  12/6/2012     22:22           NaN             M          1954.0
# 65532  12/6/2012     23:20           NaN             M          1985.0
# 65533  12/7/2012      0:23           NaN           NaN             NaN
# 65534  12/7/2012      0:30           NaN             F          1985.0
#
#        driver_age driver_race                   violation_raw  violation  \
# ...

# %% [markdown]
# ### head() - It shows the first N rows in the data (by default, N=5)

# %%
df.head()
# Out:
#    stop_date stop_time  country_name driver_gender  driver_age_raw  \
# 0   1/2/2005      1:55           NaN             M          1985.0
# 1  1/18/2005      8:15           NaN             M          1965.0
# 2  1/23/2005     23:15           NaN             M          1972.0
# 3  2/20/2005     17:15           NaN             M          1986.0
# 4  3/14/2005     10:00           NaN             F          1984.0
#
#    driver_age driver_race     violation_raw violation  search_conducted  \
# 0        20.0       White          Speeding  Speeding             False
# 1        40.0       White          Speeding  Speeding             False
# 2        33.0       White          Speeding  Speeding             False
# 3        19.0       White  Call for Service     Other             False
# 4        21.0       White          Speeding  Speeding             False
#
#   search_type   stop_outcome is_arrested stop_duration  drugs_related_stop
# ...

# %% [markdown]
# ### df.isnull( ).sum( ) - It detects the missing values from each column of the dataframe.

# %%
df.isna().sum()
# Out:
# stop_date                 0
# stop_time                 0
# country_name          65535
# driver_gender          4061
# driver_age_raw         4054
# driver_age             4307
# driver_race            4060
# violation_raw          4060
# violation              4060
# search_conducted          0
# search_type           63056
# stop_outcome           4060
# is_arrested            4060
# stop_duration          4060
# drugs_related_stop        0
# dtype: int64

# %% [markdown]
# ### df.drop(‘Col_name’ )   - To drop a column from dataframe.

# %%
# its values only nan so its useless column
df.drop(columns=['country_name'],inplace=True)

# %%
df
# Out:
#        stop_date stop_time driver_gender  driver_age_raw  driver_age  \
# 0       1/2/2005      1:55             M          1985.0        20.0
# 1      1/18/2005      8:15             M          1965.0        40.0
# 2      1/23/2005     23:15             M          1972.0        33.0
# 3      2/20/2005     17:15             M          1986.0        19.0
# 4      3/14/2005     10:00             F          1984.0        21.0
# ...          ...       ...           ...             ...         ...
# 65530  12/6/2012     17:54             F          1987.0        25.0
# 65531  12/6/2012     22:22             M          1954.0        58.0
# 65532  12/6/2012     23:20             M          1985.0        27.0
# 65533  12/7/2012      0:23           NaN             NaN         NaN
# 65534  12/7/2012      0:30             F          1985.0        27.0
#
#       driver_race                   violation_raw  violation  \
# 0           White                        Speeding   Speeding
# ...

# %% [markdown]
# ### value_counts - In a column, it shows all the unique values with their count. It can be applied on a single column only.

# %%
df.driver_race.value_counts()
# Out:
# White       45747
# Black        8267
# Hispanic     5611
# Asian        1639
# Other         211
# Name: driver_race, dtype: int64

# %% [markdown]
# ### df.groupby(‘Col_1’)[‘Col_2’] .sum( ) - To create groups - Two Keys – Apply on Col_2 grouped by Col_1.

# %%
df.groupby('driver_gender')['driver_age'].mean()
# Out:
# driver_gender
# F    32.416528
# M    34.777138
# Name: driver_age, dtype: float64

# %% [markdown]
# ### df['Column_name'].map( { old1:new1 , old2:new2} ) – Change the all values of a column from old to new. We have to write for

# %%
df['driver_race'].map({'White':'W','Black':'B'})
# Out:
# 0          W
# 1          W
# 2          W
# 3          W
# 4          W
#         ...
# 65530      W
# 65531      W
# 65532      B
# 65533    NaN
# 65534      W
# Name: driver_race, Length: 65535, dtype: object

# %% [markdown]
# ### all values of column otherwise Nan will appear.

# %%
df[~(df['driver_gender'].isna())]
# Out:
#        stop_date stop_time driver_gender  driver_age_raw  driver_age  \
# 0       1/2/2005      1:55             M          1985.0        20.0
# 1      1/18/2005      8:15             M          1965.0        40.0
# 2      1/23/2005     23:15             M          1972.0        33.0
# 3      2/20/2005     17:15             M          1986.0        19.0
# 4      3/14/2005     10:00             F          1984.0        21.0
# ...          ...       ...           ...             ...         ...
# 65529  12/6/2012     16:00             M          1994.0        18.0
# 65530  12/6/2012     17:54             F          1987.0        25.0
# 65531  12/6/2012     22:22             M          1954.0        58.0
# 65532  12/6/2012     23:20             M          1985.0        27.0
# 65534  12/7/2012      0:30             F          1985.0        27.0
#
#       driver_race                   violation_raw  violation  \
# 0           White                        Speeding   Speeding
# ...

# %% [markdown]
# ### df['Column_name'].mean() - To show Mean value of a column.

# %%
df['driver_age_raw'].mean()
# Out:
# 1967.79110619541

# %% [markdown]
# ### df.groupby('Column_1').Column_2.describe() - To create groups based on Column1 and show

# %%
df.groupby('driver_race')['driver_age'].describe()
# Out:
#                count       mean        std   min   25%   50%   75%   max
# driver_race
# Asian         1634.0  33.552020  11.494403  17.0  24.0  31.0  41.0  82.0
# Black         8223.0  33.717135  11.813519  15.0  24.0  31.0  42.0  85.0
# Hispanic      5583.0  32.001254  10.774329  15.0  23.0  29.0  39.0  76.0
# Other          210.0  34.900000  11.914147  18.0  25.0  32.0  42.0  74.0
# White        45573.0  34.508591  13.161904  15.0  23.0  31.0  44.0  88.0

# %% [markdown]
# ### Q. 1) Instruction ( For Data Cleaning ) - Remove the column that only contains missing values.

# %%
df.drop(columns=['country_name'],inplace=True) 
df
# Out:
#        stop_date stop_time driver_gender  driver_age_raw  driver_age  \
# 0       1/2/2005      1:55             M          1985.0        20.0
# 1      1/18/2005      8:15             M          1965.0        40.0
# 2      1/23/2005     23:15             M          1972.0        33.0
# 3      2/20/2005     17:15             M          1986.0        19.0
# 4      3/14/2005     10:00             F          1984.0        21.0
# ...          ...       ...           ...             ...         ...
# 65530  12/6/2012     17:54             F          1987.0        25.0
# 65531  12/6/2012     22:22             M          1954.0        58.0
# 65532  12/6/2012     23:20             M          1985.0        27.0
# 65533  12/7/2012      0:23           NaN             NaN         NaN
# 65534  12/7/2012      0:30             F          1985.0        27.0
#
#       driver_race                   violation_raw  violation  \
# 0           White                        Speeding   Speeding
# ...

# %% [markdown]
# ### Q. 2) Question ( Based on Filtering + Value Counts ) - For Speeding , were Men or Women stopped more often ?

# %%
speeding = df[df['violation'] == 'Speeding']
speeding['driver_gender'].value_counts()
# Out:
# M    25517
# F    11686
# Name: driver_gender, dtype: int64

# %% [markdown]
# ### Q. 3) Question ( Groupby ) - Does gender affect who gets searched during a stop ?

# %%
df['search_conducted'].unique()
# Out:
# array([False,  True])

# %%
df.groupby('driver_gender')['search_conducted'].sum()
# Out:
# driver_gender
# F     366
# M    2113
# Name: search_conducted, dtype: int64

# %%
df['search_conducted'].value_counts()
# Out:
# False    63056
# True      2479
# Name: search_conducted, dtype: int64

# %% [markdown]
# ### Question ( mapping + data-type casting )
# Q. 4) Question ( mapping + data-type casting ) - What is the mean stop_duration ?

# %%
df['stop_duration'] = df['stop_duration'].map({'0-15 Min': 7.5, '16-30 Min': 24, '30+ Min': 45})

# %%
df.stop_duration.dtype
df
# Out:
#        stop_date stop_time driver_gender  driver_age_raw  driver_age  \
# 0       1/2/2005      1:55             M          1985.0        20.0
# 1      1/18/2005      8:15             M          1965.0        40.0
# 2      1/23/2005     23:15             M          1972.0        33.0
# 3      2/20/2005     17:15             M          1986.0        19.0
# 4      3/14/2005     10:00             F          1984.0        21.0
# ...          ...       ...           ...             ...         ...
# 65530  12/6/2012     17:54             F          1987.0        25.0
# 65531  12/6/2012     22:22             M          1954.0        58.0
# 65532  12/6/2012     23:20             M          1985.0        27.0
# 65533  12/7/2012      0:23           NaN             NaN         NaN
# 65534  12/7/2012      0:30             F          1985.0        27.0
#
#       driver_race                   violation_raw  violation  \
# 0           White                        Speeding   Speeding
# ...

# %%
df.stop_duration.mean()
# Out:
# 12.187420698181345

# %% [markdown]
# ### Q. 5) Question ( Groupby , Describe ) - Compare the age distributions for each violation.

# %%
df.groupby('violation')['driver_age'].describe()
# Out:
#                        count       mean        std   min   25%   50%   75%  \
# violation
# Equipment             6507.0  31.682957  11.380671  16.0  23.0  28.0  39.0
# Moving violation     11876.0  36.736443  13.258350  15.0  25.0  35.0  47.0
# Other                 3477.0  40.362381  12.754423  16.0  30.0  41.0  50.0
# Registration/plates   2240.0  32.656696  11.150780  16.0  24.0  30.0  40.0
# Seat belt                3.0  30.333333  10.214369  23.0  24.5  26.0  34.0
# Speeding             37120.0  33.262581  12.615781  15.0  23.0  30.0  42.0
#
#                       max
# violation
# Equipment            81.0
# Moving violation     86.0
# Other                86.0
# Registration/plates  74.0
# Seat belt            42.0
# Speeding             88.0

# %% [markdown]
# ### Q. 6) which race did more stop according to gender

# %%
sns.countplot(data=df,x = 'driver_gender', hue= 'driver_race',palette='magma')
# Out:
# <AxesSubplot:xlabel='driver_gender', ylabel='count'>

# %% [markdown]
# ### Q. 7) findout the most  violation type

# %%
sns.countplot(data=df, x= 'violation',palette='rocket')
# Out:
# <AxesSubplot:xlabel='violation', ylabel='count'>

# %% [markdown]
# ### Q. 8) what is most age that getting stoped

# %%
x = df['driver_age'].value_counts().head(10)
x # as we see its related to age the more person is younger the more liklehood doing unusual behavior
# Out:
# 22.0    2912
# 21.0    2886
# 20.0    2783
# 23.0    2725
# 24.0    2583
# 19.0    2388
# 25.0    2357
# 26.0    2254
# 27.0    2047
# 28.0    1869
# Name: driver_age, dtype: int64

# %%
df.groupby('driver_gender')['driver_age'].value_counts().head(100)
# Out:
# driver_gender  driver_age
# F              20.0          932
#                21.0          931
#                22.0          894
#                23.0          814
#                24.0          764
#                             ...
# M              41.0          851
#                45.0          791
#                46.0          774
#                48.0          767
#                47.0          729
# Name: driver_age, Length: 100, dtype: int64

# %%
y = sns.countplot(data=df[df['driver_age'].isin(x.index)],x= 'driver_age',order=x.index,hue= 'driver_gender',palette='summer' )
y.figure.suptitle('most age that getting stoped according to gender')
# Out:
# Text(0.5, 0.98, 'most age that getting stoped according to gender')

# %% [markdown]
# #### By Anas Awad
